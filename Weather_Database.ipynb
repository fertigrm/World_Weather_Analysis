# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import gmaps
import requests
from config import weather_api_key
from config import g_key
import time
from datetime import datetime
from scipy.stats import linregress

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# Create an empty list to hold the weather data.
# city_data = []
# Print the beginning of the logging.
# print("Beginning Data Retrieval     ")
#  print("-----------------------------")

# Create counters.
#record_count = 1
#set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | ponta do sol
# Processing Record 2 of Set 1 | kontagora
# Processing Record 3 of Set 1 | husavik
# Processing Record 4 of Set 1 | la ronge
# Processing Record 5 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 6 of Set 1 | east london
# Processing Record 7 of Set 1 | nouadhibou
# Processing Record 8 of Set 1 | bambous virieux
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | middleton
# Processing Record 11 of Set 1 | hasaki
# Processing Record 12 of Set 1 | ust-nera
# Processing Record 13 of Set 1 | hilo
# Processing Record 14 of Set 1 | elban
# Processing Record 15 of Set 1 | ponta delgada
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | beitbridge
# Processing Record 18 of Set 1 | hovd
# Processing Record 19 of Set 1 | chuy
# Processing Record 20 of Set 1 | coxim
# Processing Record 21 of Set 1 | goba
# Processing Record 22 of Set 1 | maniitsoq
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | rio gallegos
# Processing Record 25 of Set 1 | karasburg
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | new norfolk
# Processing Record 28 of Set 1 | castro
# Processing Record 29 of Set 1 | inuvik
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | sulya
# Processing Record 35 of Set 1 | roma
# Processing Record 36 of Set 1 | airai
# Processing Record 37 of Set 1 | palampur
# Processing Record 38 of Set 1 | sept-iles
# Processing Record 39 of Set 1 | sinjar
# Processing Record 40 of Set 1 | san cristobal
# Processing Record 41 of Set 1 | pevek
# Processing Record 42 of Set 1 | ribeira grande
# Processing Record 43 of Set 1 | esperance
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | filingue
# Processing Record 46 of Set 1 | vostok
# Processing Record 47 of Set 1 | hobart
# Processing Record 48 of Set 1 | dikson
# Processing Record 49 of Set 1 | guilin
# Processing Record 50 of Set 1 | sao pedro do sul
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 2 | upernavik
# Processing Record 4 of Set 2 | luderitz
# Processing Record 5 of Set 2 | fort saint james
# Processing Record 6 of Set 2 | aklavik
# Processing Record 7 of Set 2 | kavaratti
# Processing Record 8 of Set 2 | sorland
# Processing Record 9 of Set 2 | that phanom
# Processing Record 10 of Set 2 | yulara
# Processing Record 11 of Set 2 | zaysan
# Processing Record 12 of Set 2 | vaini
# Processing Record 13 of Set 2 | parana
# Processing Record 14 of Set 2 | teyateyaneng
# Processing Record 15 of Set 2 | barcelos
# Processing Record 16 of Set 2 | carutapera
# Processing Record 17 of Set 2 | saskylakh
# Processing Record 18 of Set 2 | techiman
# Processing Record 19 of Set 2 | camacha
# Processing Record 20 of Set 2 | taltal
# Processing Record 21 of Set 2 | vila velha
# Processing Record 22 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 2 | barth
# Processing Record 24 of Set 2 | tasiilaq
# Processing Record 25 of Set 2 | abha
# Processing Record 26 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 2 | tuktoyaktuk
# Processing Record 28 of Set 2 | rocha
# Processing Record 29 of Set 2 | touros
# Processing Record 30 of Set 2 | enshi
# Processing Record 31 of Set 2 | kijang
# Processing Record 32 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 33 of Set 2 | athabasca
# Processing Record 34 of Set 2 | cape town
# Processing Record 35 of Set 2 | spasskoye
# Processing Record 36 of Set 2 | coswig
# Processing Record 37 of Set 2 | port lincoln
# Processing Record 38 of Set 2 | dorado
# Processing Record 39 of Set 2 | pafos
# Processing Record 40 of Set 2 | eseka
# Processing Record 41 of Set 2 | fort nelson
# Processing Record 42 of Set 2 | avarua
# Processing Record 43 of Set 2 | veraval
# Processing Record 44 of Set 2 | khatanga
# Processing Record 45 of Set 2 | yuncheng
# Processing Record 46 of Set 2 | qaanaaq
# Processing Record 47 of Set 2 | vardo
# Processing Record 48 of Set 2 | pangnirtung
# Processing Record 49 of Set 2 | santa maria da boa vista
# Processing Record 50 of Set 2 | nagarote
# Processing Record 1 of Set 3 | port elizabeth
# Processing Record 2 of Set 3 | hermanus
# Processing Record 3 of Set 3 | tiksi
# Processing Record 4 of Set 3 | miramar
# Processing Record 5 of Set 3 | barrow
# Processing Record 6 of Set 3 | shcherbynivka
# Processing Record 7 of Set 3 | luanda
# Processing Record 8 of Set 3 | mpanda
# Processing Record 9 of Set 3 | christchurch
# Processing Record 10 of Set 3 | belle fourche
# Processing Record 11 of Set 3 | monrovia
# Processing Record 12 of Set 3 | elk grove village
# Processing Record 13 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 14 of Set 3 | alofi
# Processing Record 15 of Set 3 | north myrtle beach
# Processing Record 16 of Set 3 | kapaa
# Processing Record 17 of Set 3 | ilulissat
# Processing Record 18 of Set 3 | gotsu
# Processing Record 19 of Set 3 | nioro
# Processing Record 20 of Set 3 | bayir
# Processing Record 21 of Set 3 | jamestown
# Processing Record 22 of Set 3 | faya
# Processing Record 23 of Set 3 | leningradskiy
# Processing Record 24 of Set 3 | funadhoo
# Processing Record 25 of Set 3 | dalvik
# Processing Record 26 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 3 | kargasok
# Processing Record 28 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 3 | karratha
# Processing Record 30 of Set 3 | georgetown
# Processing Record 31 of Set 3 | stornoway
# Processing Record 32 of Set 3 | jumla
# Processing Record 33 of Set 3 | illapel
# Processing Record 34 of Set 3 | bathsheba
# Processing Record 35 of Set 3 | severo-kurilsk
# Processing Record 36 of Set 3 | urdzhar
# City not found. Skipping...
# Processing Record 37 of Set 3 | gidam
# Processing Record 38 of Set 3 | kruisfontein
# Processing Record 39 of Set 3 | gizo
# Processing Record 40 of Set 3 | darnah
# Processing Record 41 of Set 3 | yellowknife
# Processing Record 42 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 3 | charters towers
# Processing Record 44 of Set 3 | inirida
# Processing Record 45 of Set 3 | nikolskoye
# Processing Record 46 of Set 3 | torres
# Processing Record 47 of Set 3 | nishihara
# Processing Record 48 of Set 3 | espinosa
# Processing Record 49 of Set 3 | constitucion
# Processing Record 50 of Set 3 | port alfred
# Processing Record 1 of Set 4 | whitecourt
# Processing Record 2 of Set 4 | torbay
# Processing Record 3 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 4 | provideniya
# Processing Record 5 of Set 4 | katherine
# Processing Record 6 of Set 4 | saint anthony
# Processing Record 7 of Set 4 | bacungan
# Processing Record 8 of Set 4 | kodiak
# Processing Record 9 of Set 4 | havelock
# Processing Record 10 of Set 4 | faanui
# Processing Record 11 of Set 4 | emerald
# Processing Record 12 of Set 4 | bethel
# Processing Record 13 of Set 4 | cervo
# Processing Record 14 of Set 4 | banda aceh
# Processing Record 15 of Set 4 | porto walter
# Processing Record 16 of Set 4 | urumqi
# Processing Record 17 of Set 4 | plouzane
# Processing Record 18 of Set 4 | sitka
# Processing Record 19 of Set 4 | san quintin
# Processing Record 20 of Set 4 | srednekolymsk
# Processing Record 21 of Set 4 | carnarvon
# Processing Record 22 of Set 4 | axim
# Processing Record 23 of Set 4 | paamiut
# Processing Record 24 of Set 4 | kavieng
# Processing Record 25 of Set 4 | rawson
# Processing Record 26 of Set 4 | tabialan
# City not found. Skipping...
# Processing Record 27 of Set 4 | hualmay
# Processing Record 28 of Set 4 | hailey
# Processing Record 29 of Set 4 | sinnamary
# Processing Record 30 of Set 4 | orange
# Processing Record 31 of Set 4 | nakamura
# Processing Record 32 of Set 4 | kachug
# Processing Record 33 of Set 4 | terrace
# Processing Record 34 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 35 of Set 4 | tubruq
# City not found. Skipping...
# Processing Record 36 of Set 4 | chapais
# Processing Record 37 of Set 4 | cherskiy
# Processing Record 38 of Set 4 | lavrentiya
# Processing Record 39 of Set 4 | matagami
# Processing Record 40 of Set 4 | vestmannaeyjar
# Processing Record 41 of Set 4 | port hardy
# Processing Record 42 of Set 4 | cabinda
# Processing Record 43 of Set 4 | prevalje
# Processing Record 44 of Set 4 | pasir gudang
# Processing Record 45 of Set 4 | fairbanks
# Processing Record 46 of Set 4 | souillac
# Processing Record 47 of Set 4 | yar-sale
# Processing Record 48 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 4 | sakaiminato
# Processing Record 50 of Set 4 | limbang
# Processing Record 1 of Set 5 | arraial do cabo
# Processing Record 2 of Set 5 | nabire
# Processing Record 3 of Set 5 | vanimo
# Processing Record 4 of Set 5 | nuzvid
# Processing Record 5 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 6 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 7 of Set 5 | aquiraz
# Processing Record 8 of Set 5 | mar del plata
# Processing Record 9 of Set 5 | saldanha
# Processing Record 10 of Set 5 | moba
# Processing Record 11 of Set 5 | beloha
# Processing Record 12 of Set 5 | ust-maya
# Processing Record 13 of Set 5 | ovre ardal
# Processing Record 14 of Set 5 | xining
# Processing Record 15 of Set 5 | ligayan
# Processing Record 16 of Set 5 | tanete
# Processing Record 17 of Set 5 | medea
# Processing Record 18 of Set 5 | victoria
# Processing Record 19 of Set 5 | praya
# Processing Record 20 of Set 5 | butaritari
# Processing Record 21 of Set 5 | palmer
# Processing Record 22 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 5 | tecoanapa
# Processing Record 24 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 5 | lompoc
# Processing Record 26 of Set 5 | norman wells
# Processing Record 27 of Set 5 | ulagan
# Processing Record 28 of Set 5 | the valley
# Processing Record 29 of Set 5 | warkworth
# Processing Record 30 of Set 5 | miri
# Processing Record 31 of Set 5 | san giuseppe jato
# Processing Record 32 of Set 5 | berlevag
# Processing Record 33 of Set 5 | poum
# Processing Record 34 of Set 5 | teguise
# Processing Record 35 of Set 5 | lata
# Processing Record 36 of Set 5 | yate
# Processing Record 37 of Set 5 | necochea
# Processing Record 38 of Set 5 | kuito
# Processing Record 39 of Set 5 | mataura
# Processing Record 40 of Set 5 | rabo de peixe
# Processing Record 41 of Set 5 | atoka
# Processing Record 42 of Set 5 | bluff
# Processing Record 43 of Set 5 | coos bay
# Processing Record 44 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 5 | korla
# Processing Record 46 of Set 5 | maputo
# Processing Record 47 of Set 5 | sur
# Processing Record 48 of Set 5 | bengkulu
# Processing Record 49 of Set 5 | saint george
# Processing Record 50 of Set 5 | uwajima
# Processing Record 1 of Set 6 | tuatapere
# Processing Record 2 of Set 6 | kirakira
# Processing Record 3 of Set 6 | worland
# Processing Record 4 of Set 6 | nanortalik
# Processing Record 5 of Set 6 | goderich
# Processing Record 6 of Set 6 | gillette
# Processing Record 7 of Set 6 | kaitangata
# Processing Record 8 of Set 6 | salalah
# Processing Record 9 of Set 6 | znamenka
# Processing Record 10 of Set 6 | kirkwall
# Processing Record 11 of Set 6 | cap malheureux
# Processing Record 12 of Set 6 | hithadhoo
# Processing Record 13 of Set 6 | burns lake
# Processing Record 14 of Set 6 | puerto madryn
# Processing Record 15 of Set 6 | benguela
# Processing Record 16 of Set 6 | general roca
# Processing Record 17 of Set 6 | ritchie
# Processing Record 18 of Set 6 | yeletskiy
# City not found. Skipping...
# Processing Record 19 of Set 6 | iquique
# Processing Record 20 of Set 6 | adrar
# Processing Record 21 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 22 of Set 6 | eyl
# Processing Record 23 of Set 6 | hambantota
# Processing Record 24 of Set 6 | novaya igirma
# Processing Record 25 of Set 6 | belem de sao francisco
# Processing Record 26 of Set 6 | weiser
# Processing Record 27 of Set 6 | mukhen
# Processing Record 28 of Set 6 | ballina
# Processing Record 29 of Set 6 | te anau
# Processing Record 30 of Set 6 | honiara
# Processing Record 31 of Set 6 | waingapu
# Processing Record 32 of Set 6 | olga
# Processing Record 33 of Set 6 | cidreira
# Processing Record 34 of Set 6 | saint-philippe
# Processing Record 35 of Set 6 | coquimbo
# Processing Record 36 of Set 6 | deer lake
# Processing Record 37 of Set 6 | calabozo
# Processing Record 38 of Set 6 | codrington
# Processing Record 39 of Set 6 | san policarpo
# Processing Record 40 of Set 6 | chapleau
# Processing Record 41 of Set 6 | hobyo
# Processing Record 42 of Set 6 | muros
# Processing Record 43 of Set 6 | ondorhaan
# City not found. Skipping...
# Processing Record 44 of Set 6 | acajutla
# Processing Record 45 of Set 6 | grand gaube
# Processing Record 46 of Set 6 | lebu
# Processing Record 47 of Set 6 | bogale
# Processing Record 48 of Set 6 | fortuna
# Processing Record 49 of Set 6 | sao filipe
# Processing Record 50 of Set 6 | padang
# Processing Record 1 of Set 7 | san jose
# Processing Record 2 of Set 7 | launceston
# Processing Record 3 of Set 7 | camara de lobos
# Processing Record 4 of Set 7 | sovetskiy
# Processing Record 5 of Set 7 | terney
# Processing Record 6 of Set 7 | mwinilunga
# Processing Record 7 of Set 7 | marsh harbour
# Processing Record 8 of Set 7 | galdar
# Processing Record 9 of Set 7 | bam
# Processing Record 10 of Set 7 | honningsvag
# Processing Record 11 of Set 7 | doha
# Processing Record 12 of Set 7 | lucatan
# City not found. Skipping...
# Processing Record 13 of Set 7 | tigil
# Processing Record 14 of Set 7 | amazar
# Processing Record 15 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 16 of Set 7 | san patricio
# Processing Record 17 of Set 7 | lakatoro
# Processing Record 18 of Set 7 | khash
# Processing Record 19 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 20 of Set 7 | itarema
# Processing Record 21 of Set 7 | naze
# Processing Record 22 of Set 7 | lagoa vermelha
# Processing Record 23 of Set 7 | meulaboh
# Processing Record 24 of Set 7 | cherepovets
# Processing Record 25 of Set 7 | durant
# Processing Record 26 of Set 7 | oyama
# Processing Record 27 of Set 7 | myanaung
# Processing Record 28 of Set 7 | seymchan
# Processing Record 29 of Set 7 | graaff-reinet
# Processing Record 30 of Set 7 | labuhan
# Processing Record 31 of Set 7 | san carlos
# Processing Record 32 of Set 7 | batemans bay
# Processing Record 33 of Set 7 | sioux lookout
# Processing Record 34 of Set 7 | santa cruz
# Processing Record 35 of Set 7 | jalingo
# Processing Record 36 of Set 7 | acari
# Processing Record 37 of Set 7 | praia da vitoria
# Processing Record 38 of Set 7 | pyay
# Processing Record 39 of Set 7 | bilibino
# Processing Record 40 of Set 7 | mahebourg
# Processing Record 41 of Set 7 | kananga
# Processing Record 42 of Set 7 | alamos
# Processing Record 43 of Set 7 | cao bang
# Processing Record 44 of Set 7 | wewak
# Processing Record 45 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 7 | pisco
# Processing Record 47 of Set 7 | nome
# Processing Record 48 of Set 7 | grindavik
# Processing Record 49 of Set 7 | broome
# Processing Record 50 of Set 7 | buraydah
# Processing Record 1 of Set 8 | uthal
# Processing Record 2 of Set 8 | clyde river
# Processing Record 3 of Set 8 | astoria
# Processing Record 4 of Set 8 | santa maria
# Processing Record 5 of Set 8 | geraldton
# Processing Record 6 of Set 8 | khuzdar
# Processing Record 7 of Set 8 | ust-kuyga
# Processing Record 8 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 8 | ormara
# Processing Record 10 of Set 8 | methoni
# Processing Record 11 of Set 8 | kaeo
# Processing Record 12 of Set 8 | miraflores
# Processing Record 13 of Set 8 | merauke
# Processing Record 14 of Set 8 | port shepstone
# Processing Record 15 of Set 8 | ahumada
# City not found. Skipping...
# Processing Record 16 of Set 8 | red bluff
# Processing Record 17 of Set 8 | santa fe
# Processing Record 18 of Set 8 | avera
# Processing Record 19 of Set 8 | caravelas
# Processing Record 20 of Set 8 | komsomolskiy
# Processing Record 21 of Set 8 | thunder bay
# Processing Record 22 of Set 8 | jalu
# Processing Record 23 of Set 8 | sale
# Processing Record 24 of Set 8 | sedniv
# Processing Record 25 of Set 8 | katangli
# Processing Record 26 of Set 8 | palauig
# Processing Record 27 of Set 8 | anadyr
# Processing Record 28 of Set 8 | porto novo
# Processing Record 29 of Set 8 | talca
# Processing Record 30 of Set 8 | dutlwe
# Processing Record 31 of Set 8 | kaliyaganj
# Processing Record 32 of Set 8 | zyryanka
# Processing Record 33 of Set 8 | forbes
# Processing Record 34 of Set 8 | hirara
# Processing Record 35 of Set 8 | marzuq
# Processing Record 36 of Set 8 | khasan
# Processing Record 37 of Set 8 | ovalle
# Processing Record 38 of Set 8 | warrington
# Processing Record 39 of Set 8 | kodinar
# Processing Record 40 of Set 8 | chiredzi
# Processing Record 41 of Set 8 | pringsewu
# Processing Record 42 of Set 8 | gladstone
# Processing Record 43 of Set 8 | trairi
# Processing Record 44 of Set 8 | korem
# Processing Record 45 of Set 8 | mount gambier
# Processing Record 46 of Set 8 | buala
# Processing Record 47 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 8 | nemours
# Processing Record 49 of Set 8 | ancud
# Processing Record 50 of Set 8 | yelizovo
# Processing Record 1 of Set 9 | beni
# Processing Record 2 of Set 9 | dubasari
# Processing Record 3 of Set 9 | logan lake
# Processing Record 4 of Set 9 | nantucket
# Processing Record 5 of Set 9 | kieta
# Processing Record 6 of Set 9 | mendahara
# City not found. Skipping...
# Processing Record 7 of Set 9 | cantaura
# Processing Record 8 of Set 9 | oranjemund
# Processing Record 9 of Set 9 | mozhga
# Processing Record 10 of Set 9 | atasu
# Processing Record 11 of Set 9 | llanes
# Processing Record 12 of Set 9 | takoradi
# Processing Record 13 of Set 9 | san-pedro
# Processing Record 14 of Set 9 | tarakan
# Processing Record 15 of Set 9 | sharan
# Processing Record 16 of Set 9 | arcachon
# Processing Record 17 of Set 9 | coihaique
# Processing Record 18 of Set 9 | hervey bay
# Processing Record 19 of Set 9 | sesheke
# Processing Record 20 of Set 9 | vao
# Processing Record 21 of Set 9 | san jose poaquil
# Processing Record 22 of Set 9 | salinopolis
# Processing Record 23 of Set 9 | longyearbyen
# Processing Record 24 of Set 9 | jiangyou
# Processing Record 25 of Set 9 | kathu
# Processing Record 26 of Set 9 | cayenne
# Processing Record 27 of Set 9 | panlaitan
# Processing Record 28 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 29 of Set 9 | dunedin
# Processing Record 30 of Set 9 | thilogne
# City not found. Skipping...
# Processing Record 31 of Set 9 | isangel
# Processing Record 32 of Set 9 | desaguadero
# Processing Record 33 of Set 9 | vila do maio
# Processing Record 34 of Set 9 | azul
# Processing Record 35 of Set 9 | sola
# Processing Record 36 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 37 of Set 9 | camaiore
# Processing Record 38 of Set 9 | guerrero negro
# Processing Record 39 of Set 9 | maua
# Processing Record 40 of Set 9 | yakeshi
# Processing Record 41 of Set 9 | chokurdakh
# Processing Record 42 of Set 9 | macherla
# Processing Record 43 of Set 9 | saint-augustin
# Processing Record 44 of Set 9 | qaqortoq
# Processing Record 45 of Set 9 | george
# Processing Record 46 of Set 9 | ponyri
# Processing Record 47 of Set 9 | nchelenge
# Processing Record 48 of Set 9 | bangkal
# Processing Record 49 of Set 9 | cassilandia
# Processing Record 50 of Set 9 | osa
# Processing Record 1 of Set 10 | inhambane
# Processing Record 2 of Set 10 | nyuksenitsa
# Processing Record 3 of Set 10 | high level
# Processing Record 4 of Set 10 | talnakh
# Processing Record 5 of Set 10 | martonvasar
# Processing Record 6 of Set 10 | tiznit
# Processing Record 7 of Set 10 | ahipara
# Processing Record 8 of Set 10 | iquitos
# Processing Record 9 of Set 10 | baykit
# Processing Record 10 of Set 10 | beringovskiy
# Processing Record 11 of Set 10 | havre-saint-pierre
# Processing Record 12 of Set 10 | shingu
# Processing Record 13 of Set 10 | mehamn
# Processing Record 14 of Set 10 | namibe
# Processing Record 15 of Set 10 | toftir
# City not found. Skipping...
# Processing Record 16 of Set 10 | orocue
# Processing Record 17 of Set 10 | beira
# Processing Record 18 of Set 10 | cabo san lucas
# Processing Record 19 of Set 10 | mufulira
# Processing Record 20 of Set 10 | morant bay
# Processing Record 21 of Set 10 | carbonia
# Processing Record 22 of Set 10 | kamaishi
# Processing Record 23 of Set 10 | teruel
# Processing Record 24 of Set 10 | jaisalmer
# Processing Record 25 of Set 10 | burica
# City not found. Skipping...
# Processing Record 26 of Set 10 | gusau
# Processing Record 27 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 28 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 10 | tokonou
# Processing Record 30 of Set 10 | chincha alta
# Processing Record 31 of Set 10 | kimbe
# Processing Record 32 of Set 10 | strand
# Processing Record 33 of Set 10 | timizart
# Processing Record 34 of Set 10 | laguna
# Processing Record 35 of Set 10 | charneca de caparica
# Processing Record 36 of Set 10 | hamadan
# Processing Record 37 of Set 10 | lethem
# Processing Record 38 of Set 10 | hurghada
# Processing Record 39 of Set 10 | suntar
# Processing Record 40 of Set 10 | champerico
# Processing Record 41 of Set 10 | vestmanna
# Processing Record 42 of Set 10 | seda
# Processing Record 43 of Set 10 | san matias
# Processing Record 44 of Set 10 | saint-joseph
# Processing Record 45 of Set 10 | san rafael
# Processing Record 46 of Set 10 | brae
# Processing Record 47 of Set 10 | vila franca do campo
# Processing Record 48 of Set 10 | henties bay
# Processing Record 49 of Set 10 | jaffna
# Processing Record 50 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 1 of Set 11 | redlands
# Processing Record 2 of Set 11 | mombetsu
# Processing Record 3 of Set 11 | sulangan
# Processing Record 4 of Set 11 | dingle
# Processing Record 5 of Set 11 | pankrushikha
# Processing Record 6 of Set 11 | ginir
# Processing Record 7 of Set 11 | dzerzhinsk
# Processing Record 8 of Set 11 | tonekabon
# Processing Record 9 of Set 11 | opuwo
# Processing Record 10 of Set 11 | linhares
# Processing Record 11 of Set 11 | zhanaozen
# Processing Record 12 of Set 11 | katsuura
# Processing Record 13 of Set 11 | noumea
# Processing Record 14 of Set 11 | kailua
# Processing Record 15 of Set 11 | north bend
# Processing Record 16 of Set 11 | saint-pierre
# Processing Record 17 of Set 11 | watrous
# Processing Record 18 of Set 11 | fare
# Processing Record 19 of Set 11 | lalomanu
# City not found. Skipping...
# Processing Record 20 of Set 11 | mandalgovi
# Processing Record 21 of Set 11 | aasiaat
# Processing Record 22 of Set 11 | iqaluit
# Processing Record 23 of Set 11 | mimongo
# Processing Record 24 of Set 11 | surskoye
# Processing Record 25 of Set 11 | rincon
# Processing Record 26 of Set 11 | otautau
# Processing Record 27 of Set 11 | pacific grove
# Processing Record 28 of Set 11 | thanh hoa
# Processing Record 29 of Set 11 | gushikawa
# Processing Record 30 of Set 11 | northam
# Processing Record 31 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 32 of Set 11 | tyukhtet
# Processing Record 33 of Set 11 | togur
# Processing Record 34 of Set 11 | lishui
# Processing Record 35 of Set 11 | ajaigarh
# Processing Record 36 of Set 11 | boguchany
# Processing Record 37 of Set 11 | rafai
# Processing Record 38 of Set 11 | salamiyah
# Processing Record 39 of Set 11 | logansport
# Processing Record 40 of Set 11 | iaciara
# Processing Record 41 of Set 11 | fontenay-le-comte
# Processing Record 42 of Set 11 | mabaruma
# Processing Record 43 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 11 | azare
# Processing Record 45 of Set 11 | hofn
# Processing Record 46 of Set 11 | cabedelo
# Processing Record 47 of Set 11 | tabou
# Processing Record 48 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 49 of Set 11 | neuquen
# Processing Record 50 of Set 11 | sonkovo
# Processing Record 1 of Set 12 | walvis bay
# Processing Record 2 of Set 12 | isla aguada
# Processing Record 3 of Set 12 | klaksvik
# Processing Record 4 of Set 12 | maragogi
# Processing Record 5 of Set 12 | zacualpan
# Processing Record 6 of Set 12 | bull savanna
# Processing Record 7 of Set 12 | lakes entrance
# Processing Record 8 of Set 12 | greeneville
# Processing Record 9 of Set 12 | camopi
# Processing Record 10 of Set 12 | bourail
# Processing Record 11 of Set 12 | hare bay
# Processing Record 12 of Set 12 | andenes
# Processing Record 13 of Set 12 | arman
# Processing Record 14 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 12 | vaitape
# Processing Record 16 of Set 12 | omsukchan
# Processing Record 17 of Set 12 | outlook
# Processing Record 18 of Set 12 | leeton
# Processing Record 19 of Set 12 | banjar
# Processing Record 20 of Set 12 | leshukonskoye
# Processing Record 21 of Set 12 | marystown
# Processing Record 22 of Set 12 | houma
# Processing Record 23 of Set 12 | nizhniy kuranakh
# Processing Record 24 of Set 12 | moranbah
# Processing Record 25 of Set 12 | kununurra
# Processing Record 26 of Set 12 | ulladulla
# Processing Record 27 of Set 12 | vallenar
# Processing Record 28 of Set 12 | haines junction
# Processing Record 29 of Set 12 | acoyapa
# Processing Record 30 of Set 12 | naryan-mar
# Processing Record 31 of Set 12 | saint-denis
# Processing Record 32 of Set 12 | huarmey
# Processing Record 33 of Set 12 | lasa
# Processing Record 34 of Set 12 | umm kaddadah
# Processing Record 35 of Set 12 | ocean city
# Processing Record 36 of Set 12 | kondapalle
# Processing Record 37 of Set 12 | libertador general san martin
# Processing Record 38 of Set 12 | flinders
# Processing Record 39 of Set 12 | greencastle
# Processing Record 40 of Set 12 | kyabram
# Processing Record 41 of Set 12 | gamba
# Processing Record 42 of Set 12 | adamas
# Processing Record 43 of Set 12 | richards bay
# Processing Record 44 of Set 12 | ust-ilimsk
# Processing Record 45 of Set 12 | chernyshevskiy
# Processing Record 46 of Set 12 | ust-barguzin
# Processing Record 47 of Set 12 | cannington
# Processing Record 48 of Set 12 | half moon bay
# Processing Record 49 of Set 12 | samarai
# Processing Record 50 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 13 | tsabong
# Processing Record 2 of Set 13 | north platte
# Processing Record 3 of Set 13 | tambacounda
# Processing Record 4 of Set 13 | arua
# Processing Record 5 of Set 13 | portland
# Processing Record 6 of Set 13 | ribeira brava
# Processing Record 7 of Set 13 | baruun-urt
# Processing Record 8 of Set 13 | rolante
# Processing Record 9 of Set 13 | uyuni
# Processing Record 10 of Set 13 | asfi
# Processing Record 11 of Set 13 | khandbari
# Processing Record 12 of Set 13 | roald
# Processing Record 13 of Set 13 | buchanan
# Processing Record 14 of Set 13 | russell
# Processing Record 15 of Set 13 | harindanga
# Processing Record 16 of Set 13 | acopiara
# Processing Record 17 of Set 13 | coronado
# Processing Record 18 of Set 13 | phangnga
# Processing Record 19 of Set 13 | namatanai
# Processing Record 20 of Set 13 | acapulco
# Processing Record 21 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 13 | lorengau
# Processing Record 23 of Set 13 | pinega
# Processing Record 24 of Set 13 | luwuk
# Processing Record 25 of Set 13 | grand-santi
# Processing Record 26 of Set 13 | aldan
# Processing Record 27 of Set 13 | yashalta
# Processing Record 28 of Set 13 | aurora
# Processing Record 29 of Set 13 | teya
# Processing Record 30 of Set 13 | belmonte
# Processing Record 31 of Set 13 | alta floresta
# Processing Record 32 of Set 13 | katobu
# Processing Record 33 of Set 13 | perth
# Processing Record 34 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 35 of Set 13 | ardabil
# Processing Record 36 of Set 13 | bud
# Processing Record 37 of Set 13 | baro
# Processing Record 38 of Set 13 | dalian
# Processing Record 39 of Set 13 | buin
# Processing Record 40 of Set 13 | freeport
# Processing Record 41 of Set 13 | narsaq
# Processing Record 42 of Set 13 | ksenyevka
# City not found. Skipping...
# Processing Record 43 of Set 13 | mandera
# Processing Record 44 of Set 13 | kurilsk
# Processing Record 45 of Set 13 | rosetta
# Processing Record 46 of Set 13 | blytheville
# Processing Record 47 of Set 13 | taoudenni
# Processing Record 48 of Set 13 | ranghulu
# Processing Record 49 of Set 13 | hamilton
# Processing Record 50 of Set 13 | gombong
# Processing Record 1 of Set 14 | dharan
# Processing Record 2 of Set 14 | ouesso
# Processing Record 3 of Set 14 | jiuquan
# Processing Record 4 of Set 14 | karatau
# Processing Record 5 of Set 14 | yenagoa
# Processing Record 6 of Set 14 | chaihe
# Processing Record 7 of Set 14 | kushima
# Processing Record 8 of Set 14 | micheweni
# Processing Record 9 of Set 14 | inta
# Processing Record 10 of Set 14 | antalaha
# Processing Record 11 of Set 14 | pombas
# Processing Record 12 of Set 14 | maceio
# Processing Record 13 of Set 14 | francavilla fontana
# Processing Record 14 of Set 14 | qui nhon
# Processing Record 15 of Set 14 | abu dhabi
# Processing Record 16 of Set 14 | yuyao
# Processing Record 17 of Set 14 | demba
# Processing Record 18 of Set 14 | juifang
# City not found. Skipping...
# Processing Record 19 of Set 14 | eenhana
# Processing Record 20 of Set 14 | ukiah
# Processing Record 21 of Set 14 | olds
# Processing Record 22 of Set 14 | santa barbara
# Processing Record 23 of Set 14 | sibolga
# Processing Record 24 of Set 14 | todos santos
# Processing Record 25 of Set 14 | petrovsk-zabaykalskiy
# Processing Record 26 of Set 14 | bedele
# Processing Record 27 of Set 14 | bafia
# Processing Record 28 of Set 14 | onguday
# Processing Record 29 of Set 14 | rusape
# Processing Record 30 of Set 14 | edson
# Processing Record 31 of Set 14 | luba
# Processing Record 32 of Set 14 | elmira
# Processing Record 33 of Set 14 | ushtobe
# Processing Record 34 of Set 14 | lumphat
# Processing Record 35 of Set 14 | sao felix do xingu
# Processing Record 36 of Set 14 | edd
# Processing Record 37 of Set 14 | ganzhou
# Processing Record 38 of Set 14 | renigunta
# Processing Record 39 of Set 14 | bang krathum
# Processing Record 40 of Set 14 | darlowo
# Processing Record 41 of Set 14 | canitas
# City not found. Skipping...
# Processing Record 42 of Set 14 | agadir
# Processing Record 43 of Set 14 | bien hoa
# Processing Record 44 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 45 of Set 14 | manzhouli
# Processing Record 46 of Set 14 | waitati
# Processing Record 47 of Set 14 | gat
# Processing Record 48 of Set 14 | asau
# Processing Record 49 of Set 14 | majene
# Processing Record 50 of Set 14 | ban dung
# Processing Record 1 of Set 15 | zatoka
# Processing Record 2 of Set 15 | bereda
# Processing Record 3 of Set 15 | mount isa
# Processing Record 4 of Set 15 | san jeronimo
# Processing Record 5 of Set 15 | pundaguitan
# Processing Record 6 of Set 15 | kisangani
# Processing Record 7 of Set 15 | kovdor
# Processing Record 8 of Set 15 | garowe
# Processing Record 9 of Set 15 | kayerkan
# Processing Record 10 of Set 15 | turan
# Processing Record 11 of Set 15 | fukue
# Processing Record 12 of Set 15 | nsanje
# Processing Record 13 of Set 15 | pedernales
# Processing Record 14 of Set 15 | sechura
# Processing Record 15 of Set 15 | gashua
# Processing Record 16 of Set 15 | tomatlan
# Processing Record 17 of Set 15 | mizdah
# Processing Record 18 of Set 15 | kasamwa
# Processing Record 19 of Set 15 | losser
# Processing Record 20 of Set 15 | crestview
# Processing Record 21 of Set 15 | cosamaloapan
# Processing Record 22 of Set 15 | skibbereen
# Processing Record 23 of Set 15 | comodoro rivadavia
# Processing Record 24 of Set 15 | huilong
# Processing Record 25 of Set 15 | homer
# Processing Record 26 of Set 15 | sakakah
# Processing Record 27 of Set 15 | sao joao da barra
# Processing Record 28 of Set 15 | lixourion
# Processing Record 29 of Set 15 | gazli
# Processing Record 30 of Set 15 | torredonjimeno
# Processing Record 31 of Set 15 | cazaje
# City not found. Skipping...
# Processing Record 32 of Set 15 | cabadiangan
# Processing Record 33 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 34 of Set 15 | lagoa
# Processing Record 35 of Set 15 | altar
# Processing Record 36 of Set 15 | ibra
# Processing Record 37 of Set 15 | sandwick
# Processing Record 38 of Set 15 | broken hill
# Processing Record 39 of Set 15 | ulaanbaatar
# Processing Record 40 of Set 15 | estelle
# Processing Record 41 of Set 15 | ambilobe
# Processing Record 42 of Set 15 | dali
# Processing Record 43 of Set 15 | sayyan
# Processing Record 44 of Set 15 | mayo
# Processing Record 45 of Set 15 | ahuimanu
# Processing Record 46 of Set 15 | krasnoselkup
# Processing Record 47 of Set 15 | puerto maldonado
# Processing Record 48 of Set 15 | ust-shonosha
# Processing Record 49 of Set 15 | jiangmen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 696

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Ponta Do Sol  32.6667  -17.1000     69.71        82           9
# 1        Kontagora  10.3999    5.4695     82.89        53          90
# 2          Husavik  66.0449  -17.3389     46.18        86          63
# 3         La Ronge  55.1001 -105.2842     48.42        49          75
# 4      East London -33.0153   27.9116     61.84        85           0
# 5       Nouadhibou  20.9310  -17.0347     75.18        64          94
# 6  Bambous Virieux -20.3428   57.7575     75.45        83          40
# 7     Puerto Ayora  -0.7393  -90.3518     73.54        94          87
# 8        Middleton  53.5500   -2.2000     57.58        91         100
# 9           Hasaki  35.7333  140.8333     55.80        89         100
#
#    Wind Speed Country                 Date
# 0        6.06      PT  2022-05-15 23:43:35
# 1        3.62      NG  2022-05-15 23:43:36
# 2        9.28      IS  2022-05-15 23:43:37
# 3       11.50      CA  2022-05-15 23:40:53
# 4        8.70      ZA  2022-05-15 23:43:37
# 5       17.27      MR  2022-05-15 23:43:38
# 6       11.50      MU  2022-05-15 23:43:15
# 7        1.01      EC  2022-05-15 23:43:39
# 8       15.64      GB  2022-05-15 23:39:00
# 9       16.13      JP  2022-05-15 23:43:40

# %%
new_column_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']

# %%
city_data_df =city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0     Ponta Do Sol      PT  2022-05-15 23:43:35  32.6667  -17.1000     69.71
# 1        Kontagora      NG  2022-05-15 23:43:36  10.3999    5.4695     82.89
# 2          Husavik      IS  2022-05-15 23:43:37  66.0449  -17.3389     46.18
# 3         La Ronge      CA  2022-05-15 23:40:53  55.1001 -105.2842     48.42
# 4      East London      ZA  2022-05-15 23:43:37 -33.0153   27.9116     61.84
# 5       Nouadhibou      MR  2022-05-15 23:43:38  20.9310  -17.0347     75.18
# 6  Bambous Virieux      MU  2022-05-15 23:43:15 -20.3428   57.7575     75.45
# 7     Puerto Ayora      EC  2022-05-15 23:43:39  -0.7393  -90.3518     73.54
# 8        Middleton      GB  2022-05-15 23:39:00  53.5500   -2.2000     57.58
# 9           Hasaki      JP  2022-05-15 23:43:40  35.7333  140.8333     55.80
#
#    Humidity  Cloudiness  Wind Speed
# 0        82           9        6.06
# 1        53          90        3.62
# 2        86          63        9.28
# 3        49          75       11.50
# 4        85           0        8.70
# 5        64          94       17.27
# 6        83          40       11.50
# 7        94          87        1.01
# 8        91         100       15.64
# 9        89         100       16.13

# %%
output_data_file = "weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
